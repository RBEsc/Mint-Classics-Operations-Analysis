# %% [markdown]
# # 🛠🏭 Project - Mint Classics Operations Analysis
# - **Company Overview**\
# Mint Classics Company, a retailer of scale-model classic model cars and other vehicles
#
# - **Business Case**\
# To support a data-based business decision, they are looking for suggestions and recommendations for reorganizing or reducing inventory, while still maintaining timely service to their customers.
#
# - **Objectives**
#     1. Explore products currently in inventory.
#     2. Determine important factors that may influence inventory reorganization/reduction.
#     3. Provide analytic insights and data-driven recommendations.

# %% [markdown]
# ## 🔢 Data provided
# - Entity Relations Diagram (ERD)
# - Data in CSV for all tables

# %% [markdown]
# ![MintClassicsDataModel.png](attachment:615e7fd4-34e5-4fda-a424-1f4a853a79e8.png)

# %% [markdown]
# - **Business Questions**
#     1) Where are items stored and if they were rearranged, could a warehouse be eliminated?
#     2) How are inventory numbers related to sales figures? Do the inventory counts seem appropriate for each item?
#     3) Are we storing items that are not moving? Are any items candidates for being dropped from the product line?

# %% [markdown]
# ## 🏭 Warehouse Analysis
# - Check current inventory per warehouse
# - Identify warehouse that can be removed and if other warehouse can accomodate the invetory

# %% [markdown]
# ![Warehouse Capacity r1.png](attachment:097e954a-38a0-49b9-8e58-6602f51ac4dd.png)

# %% [markdown]
# - Identify the sales and profit each warehouse location

# %% [markdown]
# ![Warehouse Sales_Profit.png](attachment:96e6f185-cf7b-4a38-94a9-debd3ec59de1.png)

# %% [markdown]
# **Result:**
# - South warehouse only has 79.3k units of items stored in their inventory and is a candidate for warehouse reduction.
# - Based on the available capacity of other warehouse, South Warehouse can be moved to either West or East Warehouse which has over 100K units available capacity.
# - There has also been an allocation for product to a specific warehouse,
#     - East Warehouse - Classic Cars
#     - West Warehouse - Vintage Cars
#     - North Warehouse - Motorcycles and Planes
#     - South Warehouse - Truck/Bus, Ships and Trains
# - Further analysis will be needed to understand if a more strategical allocation can be done to serve the customer better in terms of deliver lead time improvement. Balancing the products nearer to the customers will be more customer-centric approach but might affect the logistic cost.
#
# Remarks: Need to further check the actual size of the products to verify the volume capacity of plants

# %% [markdown]
# ## 💰 Sales Analysis
# - Drilling to sales per product line:
#     - **Classic cars** sales contributes to <u>40% of total sales</u> and;
#     - Bottom 3 product lines are **Planes, Ships and Trains** contributing to only <u><20% of total sales</u>.
# - Sales is well distrubuted to all products with top sales item - **1992 Ferrari 360 Spider red**, contributing to only <u>3% of total sales</u>.
#     - **1985 Toyota Supra** has no sales in the last 29 months and <u>IOH is 7,733pcs</u>.
#
# <sub>Note: IOH - Inventory on Hand<sub>

# %% [markdown]
# ![Product Sales Pareto r1.png](attachment:364a2987-3470-49e7-801a-893eeaa134f9.png)

# %% [markdown]
# ## 📊 Sales-IOH Analysis
# - Observed a huge gap in Annual Sales-IOH, Ratio of 7 to 14 can be seen in the data denoting an overstacking of across all product lines.
# - Looking at the Supply chain, proper stocking can be done to implemented for an optimized operational cost considering supplier delivery lead time, logistics and seasonal demand.
#
# <sub>Note: IOH - Inventory on Hand<sub>

# %% [markdown]
# ![Sales-IOH Map r1.png](attachment:331c3ca7-8b03-4cf6-9299-fcfef04b0207.png)

# %% [markdown]
# ## 📆🗃 Years IOH
# - Years IOH ranges from 6 to 15 years.
#     - Years IOH is an operational metrics measuring the estimated time in years to deplete the current inventory.
#
# <sub>Note: IOH - Inventory on Hand<sub>

# %% [markdown]
# ![Sales-IOH r1.png](attachment:fe3dc0c4-7264-4668-8480-7160febd4863.png)

# %% [markdown]
# ## ✅ Conclusion:
# Reviewing the Objectives and business questions:
# 1. Where are items stored and if they were rearranged, could a warehouse be eliminated? <br>**Answer:**
#     - Each warehouse are dedicated to each product lines, each warehouse hold 1-3 product lines only.
#     - South Warehouse has the least profit(USD72.7K) and profit percentage (38.7%) compared to the other three warehouses average USD103.3K in profit and 40.0% in profit percentage.
#     - Smallest warehouse is the South Warehouse and is the main candidated to be removed as East and West Warehouse has enough capacity to accomodate the inventory from South Warehouse.
# 3. How are inventory numbers related to sales figures? Do the inventory counts seem appropriate for each item? <br>**Answer:**
#     - Annual Sales-Inventory ratio has a range of 7 to 14 which means an overstocked inventory.
#     - Years IOH is also high with a range of 6 to 15 years, validating the overstocked inventory.
# 4. Are we storing items that are not moving? Are any items candidates for being dropped from the product line? <br>**Answer:**
#     - *Product-specific*
#         - 1985 Toyota Supra has no sales in the last 29 months, which can be a primary candidate to for EOL (end-of-life).
#         - While most of individual products have high inventory vs sales, these products have less than 1 year inventory based on the sales trend
#             - 1960 BSA Gold Star DBD34, 1968 Ford Mustang, 1928 Ford Phaeton Deluxe, 1997 BMW F650 ST, Pont Yacht, and F/A 18 Hornet 1/72
#     - *Product-line*
#         - Planes, Ships and Trains product lines are contributing to only <20% of total sales. These 3 product lines has 16 products which is about 15% of total SKUs.
#         - Recommending to strategize a plan with Sales and Marketing if this products will be discontinued.

# %% [markdown]
# #### Tools:
# - Data Analysis: MySQL
# - Visualization: Tableau
